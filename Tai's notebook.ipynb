# %%
import pandas as pd
pip install ggplot
# Out:
#   File "<ipython-input-34-0dda2bc04966>", line 2
#     pip install ggplot
#               ^
# SyntaxError: invalid syntax

# %%
df = [2,4,6]
df

# %%
for x in df:
    print()

# %%
import os
os.chdir("/Users/Tai/Documents/Senior Year/Clinic/")

# %%
df = pd.read_csv("RIA Stretch Wrapper Data.csv")

# %%
df.head()
# Out:
#      Time and Date  Line  Shift  loads Wraped  Pack Size  Film Brakes at Load  \
# 0  1/17/2018 16:47     1    NaN         16505        NaN                    5
# 1  1/17/2018 16:48     1    NaN         16506        NaN                    5
# 2  1/17/2018 16:49     1    NaN         16507        NaN                    5
# 3  1/17/2018 16:50     1    NaN         16508        NaN                    5
# 4  1/17/2018 16:51     1    NaN         16509        NaN                    5
#
#    Film Breaks at Clamp  Film Change  Profile Name  Rotation Up  \
# 0                     2            0            91           95
# 1                     2            0            91           95
# 2                     2            0            91           95
# 3                     2            0            91           95
# 4                     2            0            91           95
#
#        ...        OverLap Up  Overlap Down  Revolutions  Gram Weight  Girth  \
# ...

# %%
#df.hist("Gram Weight")
#pd.value_counts(df["Gram Weight"])

#pd.value_counts(df["Load payout"])

#df3 = df[df["Load payout"] == 85]
#df3 = df3[df3["Pack Size"] == 24.0]
#df3["Gram Weight"].mean()
#df3["Total Stretch On Load"].mean()
pd.value_counts(df3["Revolutions"])

#df4 = df[df["Load payout"] == 91]
#df4["Gram Weight"].mean()
#df4["Total Stretch On Load"].mean()
# Out:
# 16    62
# 15    61
# Name: Revolutions, dtype: int64
